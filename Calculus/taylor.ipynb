# %%
from manim import *
import numpy as np
# Out:
# Manim Community v0.17.1

# %%
scale = 3 * PI / 2
step = 1

config.background_color = WHITE
config.frame_width = scale * 2
config.pixel_width = 1920
config.pixel_height = 1500

# %%
a = -0.9

ca = np.cos(a)
sa = np.sin(a)


def const(x):   return ca
def first(x):   return ca - (sa * (x - a))
def second(x):  return first(x) - (ca * (x - a)**2) / 2
def third(x):   return second(x) + (sa * (x - a)**3) / 6
def fourth(x):  return third(x) + (ca * (x - a)**4) / 24
def fifth(x):   return fourth(x) - (sa * (x - a)**5) / 120

# %%
# %%manim -v WARNING Constant
#
# class Constant(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-10, 10, step),
#             y_range = (-10, 10, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         func = FunctionGraph(
#             lambda x: np.cos(x),
#             color = BLACK
#         )
#         func.stroke_width = 5
#
#         dot = Dot(point=(-0.9, np.cos(-0.9), 0), radius=0.08, color=BLACK)
#
#         taylor = DashedVMobject(FunctionGraph(
#             const,
#             color = BLACK,
#             x_range=[-3 * PI / 2, 3 * PI / 2]
#         ), dashed_ratio=0.5)
#         taylor.stroke_width = 3
#
#
#         self.add(numberplane, func, dot, taylor)

# %%
# %%manim -v WARNING FirstDegree
#
# class FirstDegree(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-10, 10, step),
#             y_range = (-10, 10, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         func = FunctionGraph(
#             lambda x: np.cos(x),
#             color = BLACK
#         )
#         func.stroke_width = 5
#
#         dot = Dot(point=(-0.9, np.cos(-0.9), 0), radius=0.08, color=BLACK)
#
#         taylor = DashedVMobject(FunctionGraph(
#             first,
#             color = BLACK,
#             x_range=[-3 * PI / 2, 3 * PI / 2]
#         ), dashed_ratio=0.5)
#
#
#         self.add(numberplane, func, dot, taylor)

# %%
# %%manim -v WARNING SecondDegree
#
# class SecondDegree(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-10, 10, step),
#             y_range = (-10, 10, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         func = FunctionGraph(
#             lambda x: np.cos(x),
#             color = BLACK
#         )
#         func.stroke_width = 5
#
#         dot = Dot(point=(-0.9, np.cos(-0.9), 0), radius=0.08, color=BLACK)
#
#         taylor = DashedVMobject(FunctionGraph(
#             second,
#             color = BLACK,
#             x_range=[-3 * PI / 2, 3 * PI / 2]
#         ), dashed_ratio=0.5, num_dashes = 23)
#
#
#         self.add(numberplane, func, dot, taylor)

# %%
# %%manim -v WARNING ThirdDegree
#
# class ThirdDegree(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-10, 10, step),
#             y_range = (-10, 10, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         func = FunctionGraph(
#             lambda x: np.cos(x),
#             color = BLACK
#         )
#         func.stroke_width = 5
#
#         dot = Dot(point=(-0.9, np.cos(-0.9), 0), radius=0.08, color=BLACK)
#
#         taylor = DashedVMobject(FunctionGraph(
#             third,
#             color = BLACK,
#             x_range=[-3 * PI / 2, 3 * PI / 2]
#         ), dashed_ratio=0.5, num_dashes = 37)
#
#
#         self.add(numberplane, func, dot, taylor)

# %%
# %%manim -v WARNING FourthDegree
#
# class FourthDegree(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-10, 10, step),
#             y_range = (-10, 10, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         func = FunctionGraph(
#             lambda x: np.cos(x),
#             color = BLACK
#         )
#         func.stroke_width = 5
#
#         dot = Dot(point=(-0.9, np.cos(-0.9), 0), radius=0.08, color=BLACK)
#
#         taylor = DashedVMobject(FunctionGraph(
#             fourth,
#             color = BLACK,
#             x_range=[-3 * PI / 2, 3 * PI / 2]
#         ), dashed_ratio=0.5, num_dashes=25)
#
#
#         self.add(numberplane, func, dot, taylor)

# %%
# %%manim -v WARNING FifthDegree
#
# class FifthDegree(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-10, 10, step),
#             y_range = (-10, 10, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         func = FunctionGraph(
#             lambda x: np.cos(x),
#             color = BLACK
#         )
#         func.stroke_width = 5
#
#         dot = Dot(point=(-0.9, np.cos(-0.9), 0), radius=0.08, color=BLACK)
#
#         taylor = DashedVMobject(FunctionGraph(
#             fifth,
#             color = BLACK,
#             x_range=[-3 * PI / 2, 3 * PI / 2]
#         ), dashed_ratio=0.5, num_dashes=57)
#
#
#         self.add(numberplane, func, dot, taylor)
