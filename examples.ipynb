# %%
from manim import *
import numpy as np
from math import sqrt
# Out:
# Manim Community v0.17.1

# %%
# %%manim -qm -v WARNING ManimCELogo
#
# class ManimCELogo(Scene):
#     def construct(self):
#         self.camera.background_color = "#ece6e2"
#         logo_green = "#87c2a5"
#         logo_blue = "#525893"
#         logo_red = "#e07a5f"
#         logo_black = "#343434"
#         ds_m = MathTex(r"\mathbb{M}", fill_color=logo_black).scale(7)
#         ds_m.shift(2.25 * LEFT + 1.5 * UP)
#         circle = Circle(color=logo_green, fill_opacity=1).shift(LEFT)
#         square = Square(color=logo_blue, fill_opacity=1).shift(UP)
#         triangle = Triangle(color=logo_red, fill_opacity=1).shift(RIGHT)
#         logo = VGroup(triangle, square, circle, ds_m)  # order matters
#         logo.move_to(ORIGIN)
#         self.add(logo)

# %%
# %%manim -qm -v WARNING VectorArrow
#
# class VectorArrow(Scene):
#     def construct(self):
#         dot = Dot(ORIGIN)
#         arrow = Arrow(ORIGIN, [2, 2, 0], buff=0)
#         numberplane = NumberPlane()
#         origin_text = Text('(0, 0)').next_to(dot, DOWN)
#         tip_text = Text('(2, 2)').next_to(arrow.get_end(), RIGHT)
#         self.add(numberplane, dot, arrow, origin_text, tip_text)

# %%
# %%manim -qm -v WARNING BraceAnnotation
#
# class BraceAnnotation(Scene):
#     def construct(self):
#         dot = Dot([-2, -1, 0])
#         dot2 = Dot([2, 1, 0])
#         line = Line(dot.get_center(), dot2.get_center()).set_color(ORANGE)
#         b1 = Brace(line)
#         b1text = b1.get_text("Horizontal distance")
#         b2 = Brace(line, direction=line.copy().rotate(PI / 2).get_unit_vector())
#         b2text = b2.get_tex("x-x_1")
#         self.add(line, dot, dot2, b1, b2, b1text, b2text)

# %%
from manim import *

class PolarGraphExample(Scene):
    def construct(self):
        plane = PolarPlane()
        r = lambda theta: 2 * np.sin(theta * 5)
        graph = plane.plot_polar_graph(r, [0, 2 * PI], color=ORANGE)
        self.add(plane, graph)

# %%
# %%manim -qm -v WARNING ExampleFunctionGraph
#
# class ExampleFunctionGraph(Scene):
#     def construct(self):
#         cos_func = FunctionGraph(
#             lambda t: np.cos(t) + 0.5 * np.cos(7 * t) + (1 / 7) * np.cos(14 * t),
#             color=RED,
#         )
#
#         sin_func_1 = FunctionGraph(
#             lambda t: np.sin(t) + 0.5 * np.sin(7 * t) + (1 / 7) * np.sin(14 * t),
#             color=BLUE,
#         )
#
#         sin_func_2 = FunctionGraph(
#             lambda t: np.sin(t) + 0.5 * np.sin(7 * t) + (1 / 7) * np.sin(14 * t),
#             x_range=[-4, 4],
#             color=GREEN,
#         ).move_to([0, 1, 0])
#
#         self.add(cos_func, sin_func_1, sin_func_2)

# %%
# %%manim -qm -v WARNING Formula
#
# class Formula(Scene):
#     def construct(self):
#         t = MathTex(r"\int_a^b f'(x) dx = f(b)- f(a)")
#         self.add(t)

# %%
# %%manim -v WARNING ImplicitFunctionExample
#
# class ImplicitFunctionExample(Scene):
#     def construct(self):
#         graph = ImplicitFunction(
#             lambda x, y: x * y ** 2 - x ** 2 * y - 2,
#             color=YELLOW
#         )
#         self.add(NumberPlane(), graph)

# %%
# %%manim -v WARNING ConicExample
#
# class ConicExample(Scene):
#     def construct(self):
#         graph = ImplicitFunction(
#             lambda x, y: x**2 + y**2 - 1,
#             color=YELLOW
#         )
#         self.add(NumberPlane(), graph)

# %%
# %%manim -v WARNING ComplexPlaneExample
#
# class ComplexPlaneExample(Scene):
#     def construct(self):
#         plane = ComplexPlane().add_coordinates()
#         self.add(plane)
#         d1 = Dot(plane.n2p(2 + 1j), color=YELLOW)
#         d2 = Dot(plane.n2p(-3 - 2j), color=YELLOW)
#         label1 = MathTex("2+i").next_to(d1, UR, 0.1)
#         label2 = MathTex("-3-2i").next_to(d2, UR, 0.1)
#         self.add(d1, label1, d2, label2)

# %%
# %%manim -v WARNING PolarPlaneExample
#
# class PolarPlaneExample(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size=10,
#             # azimuth_label_font_size=33.6,
#             # radius_config={"font_size": 33.6},
#         ) #.add_coordinates()
#         self.add(polarplane_pi)

# %%
# %%manim -v WARNING PlotParametricFunction
#
# class PlotParametricFunction(Scene):
#     def func(self, t):
#         return np.array((np.sin(2 * t), np.sin(3 * t), 0))
#
#     def construct(self):
#         func = ParametricFunction(self.func, t_range = np.array([0, TAU]), fill_opacity=0).set_color(RED)
#         self.add(func.scale(3))

# %%
# %%manim -v WARNING PolygonExample
#
# class PolygonExample(Scene):
#     def construct(self):
#         isosceles = Polygon([-5, 1.5, 0], [-2, 1.5, 0], [-3.5, -2, 0])
#         position_list = [
#             [4, 1, 0],  # middle right
#             [4, -2.5, 0],  # bottom right
#             [0, -2.5, 0],  # bottom left
#             [0, 3, 0],  # top left
#             [2, 1, 0],  # middle
#             [4, 3, 0],  # top right
#         ]
#         square_and_triangles = Polygon(*position_list, color=PURPLE_B)
#         square_and_triangles.set_fill(PINK, opacity=0.5)
#         self.add(isosceles, square_and_triangles)

# %%
# %%manim -v WARNING NumberLineExample
#
# class NumberLineExample(Scene):
#     def construct(self):
#         l0 = NumberLine(
#             x_range=[-10, 10, 2],
#             length=10,
#             color=BLUE,
#             include_numbers=True,
#             label_direction=UP,
#         )
#
#         l1 = NumberLine(
#             x_range=[-10, 10, 2],
#             unit_size=0.5,
#             numbers_with_elongated_ticks=[-2, 4],
#             include_numbers=True,
#             font_size=24,
#         )
#         num6 = l1.numbers[8]
#         num6.set_color(RED)
#
#         l2 = NumberLine(
#             x_range=[-2.5, 2.5 + 0.5, 0.5],
#             length=12,
#             decimal_number_config={"num_decimal_places": 2},
#             include_numbers=True,
#         )
#
#         l3 = NumberLine(
#             x_range=[-5, 5 + 1, 1],
#             length=6,
#             include_tip=True,
#             include_numbers=True,
#             rotation=10 * DEGREES,
#         )
#
#         line_group = VGroup(l0, l1, l2, l3).arrange(DOWN, buff=1)
#         self.add(line_group)

# %%
# %%manim -v WARNING DashedVMobjectExample
#
# class DashedVMobjectExample(Scene):
#     def construct(self):
#         r = 0.5
#
#         top_row = VGroup()  # Increasing num_dashes
#         for dashes in range(1, 12):
#             circ = DashedVMobject(Circle(radius=r, color=WHITE), num_dashes=dashes)
#             top_row.add(circ)
#
#         middle_row = VGroup()  # Increasing dashed_ratio
#         for ratio in np.arange(1 / 11, 1, 1 / 11):
#             circ = DashedVMobject(
#                 Circle(radius=r, color=WHITE), dashed_ratio=ratio
#             )
#             middle_row.add(circ)
#
#         func1 = FunctionGraph(lambda t: t**5,[-1,1],color=WHITE)
#         func_even = DashedVMobject(func1,num_dashes=6,equal_lengths=True)
#         func_stretched = DashedVMobject(func1, num_dashes=6, equal_lengths=False)
#         bottom_row = VGroup(func_even,func_stretched)
#
#         top_row.arrange(buff=0.3)
#         middle_row.arrange()
#         bottom_row.arrange(buff=1)
#         everything = VGroup(top_row, middle_row, bottom_row).arrange(DOWN, buff=1)
#         self.add(everything)

# %%
from manim import *

class GetAreaExample(Scene):
    def construct(self):
        ax = Axes().add_coordinates()
        curve = ax.plot(lambda x: 2 * np.sin(x), color=DARK_BLUE)
        area = ax.get_area(
            curve,
            x_range=(PI / 2, 3 * PI / 2),
            color=(GREEN_B, GREEN_D),
            opacity=1,
        )

        self.add(ax, curve, area)

# %%
# %%manim -v WARNING BasicUsage
#
# class BasicUsage(Scene):
#     def construct(self):
#         func = lambda pos: ((1/sqrt(1 + (pos[0]*pos[1] +1)**2)) * RIGHT + ((pos[0]*pos[1] +1)/sqrt(1 + (pos[0]*pos[1] +1)**2)) * UP)
#         colors = [WHITE]
#         self.add(ArrowVectorField(func))

# %%
# %%manim -v WARNING BasicUsage
#
# class BasicUsage(Scene):
#     def construct(self):
#         func = lambda pos: (pos[0] * pos[1] + 1) * UR
#         self.add(ArrowVectorField(func),StreamLines(
#             func, x_range=[-1, 1, 0.2], y_range=[-2, 2, 0.2], padding=10
#         ))

# %%
# %%manim -v WARNING BasicUsageStream
#
# class BasicUsageStream(Scene):
#     def construct(self):
#         func = lambda pos: np.sin(pos[0]) * UR + np.cos(pos[1]) * LEFT + pos / 5
#         self.add(StreamLines(
#             func, x_range=[-1, 1, 0.2], y_range=[-2, 2, 0.2], padding=10
#         ))

# %%
# %%manim -v WARNING ComplexPlaneExample
#
# class ComplexPlaneExample(Scene):
#     def construct(self):
#         x_range = (-6, 6, 2),
#         y_range = (-6, 6, 2)
#
#         self.camera.background_color = WHITE
#
#         plane = ComplexPlane(
#             x_range = [-6, 6, 2],
#             y_range = [-4, 4, 2],
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 2
#             },
#             background_line_style = {
#                 "stroke_color": BLACK,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             }).add_coordinates()
#
#         plane.color = BLACK
#         self.add(plane)
#
#         d1 = Dot(plane.n2p(3 + 1j), color=BLACK)
#         label1 = MathTex("3 + 2i", color=BLACK).next_to(d1, UR, 0.1)
#
#         self.add(d1, label1)

# %%
# %%manim -v WARNING NumberLineExample
# config.background_color = WHITE
# config.pixel_width = 1920
# config.pixel_height = 500
# config.frame_width = 11
#
# class NumberLineExample(Scene):
#     def construct(self):
#         l0 = NumberLine(
#             x_range=[-6, 6, 1],
#             length=10,
#             color=BLACK,
#             include_numbers=True,
#             label_direction=UP,
#         )
#         l0.set_color(BLACK)
#
#         line_group = VGroup(l0).arrange(DOWN, buff=1)
#         self.add(line_group)

# %%
# scale = 10
scale = 10
step = 1

config.background_color = WHITE
config.frame_width = scale * 2
config.pixel_width = 1920
config.pixel_height = 1920

# %%
# %%manim -v WARNING ExampleFunctionGraph
#
# class ExampleFunctionGraph(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-scale, scale, step),
#             y_range = (-scale, scale, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         square = FunctionGraph(
#             lambda t: (t - 4) * t * (t + 4) * (1/12),
#             color = BLACK
#         )
#         square.stroke_width = 15
#
#         root = FunctionGraph(
#             lambda t: np.sqrt(t),
#             color = BLACK,
#             x_range=[0, 4]
#         )
#
#         folium = ImplicitFunction(
#             lambda x, y: x ** 3 + y ** 3 - 18 * x * y,
#             color = BLACK,
#             x_range = [-scale - 5, scale + 5],
#             y_range = [-scale - 5, scale + 5],
#         )
#         folium.stroke_width = 15
#
#         self.add(numberplane, square)

# %%
# %%manim -v WARNING ExampleFunctionGraph
#
# class ExampleFunctionGraph(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-scale, scale, step),
#             y_range = (-scale, scale, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         square = FunctionGraph(
#             lambda t: (t - 4) * t * (t + 4) * (1/12),
#             color = BLACK
#         )
#         square.stroke_width = 15
#
#         root = FunctionGraph(
#             lambda t: np.sqrt(t),
#             color = BLACK,
#             x_range=[0, 6]
#         )
#         root.stroke_width = 15
#
#         folium = ImplicitFunction(
#             lambda x, y: x ** 3 + y ** 3 - 18 * x * y,
#             color = BLACK,
#             x_range = [-scale - 5, scale + 5],
#             y_range = [-scale - 5, scale + 5],
#         )
#         folium.stroke_width = 15
#
#         self.add(numberplane, root)

# %%
# %%manim -v WARNING ExampleFunctionGraph
#
# class ExampleFunctionGraph(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-scale, scale, step),
#             y_range = (-scale, scale, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         square = FunctionGraph(
#             lambda t: (t - 4) * t * (t + 4) * (1/12),
#             color = BLACK
#         )
#         square.stroke_width = 7.5
#
#         root = FunctionGraph(
#             lambda t: np.sqrt(t),
#             color = BLACK,
#             x_range=[0, 4]
#         )
#
#         folium = ImplicitFunction(
#             lambda x, y: x ** 3 + y ** 3 - 18 * x * y,
#             color = BLACK,
#             x_range = [-scale - 5, scale + 5],
#             y_range = [-scale - 5, scale + 5],
#         )
#         folium.stroke_width = 15
#
#         self.add(numberplane, folium)

# %%
# %%manim -v WARNING ExampleFunctionGraph
#
# class ExampleFunctionGraph(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-scale, scale, step),
#             y_range = (-scale, scale, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         oscillating = FunctionGraph(
#             lambda t: np.sin(1/t),
#             color = BLACK
#         )
#         oscillating.stroke_width = 7.5
#
#         self.add(numberplane, oscillating)

# %%
# %%manim -v WARNING Parametric
#
# class Parametric(Scene):
#     def func(self, t):
#         return np.array((np.sin(2 * t), np.cos(3 * t), 0))
#
#     def construct(self):
#         self.camera.background_color = WHITE
#         numberplane = NumberPlane(
#             x_range = (-scale, scale, step),
#             y_range = (-scale, scale, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             })
#
#         func = ParametricFunction(self.func, t_range = np.array([0, 8 * PI/4]), fill_opacity=0).set_color(BLACK)
#         self.add(numberplane, func)

# %%
# %%manim -v WARNING ComplexPlaneExample
#
# config.frame_width = 8
#
# class ComplexPlaneExample(Scene):
#     def construct(self):
#         self.frame_width = 6
#         x_range = (-4, 4, 2),
#         y_range = (-4, 4, 2)
#
#         self.camera.background_color = WHITE
#
#         plane = ComplexPlane(
#             x_range = [-6, 6, 2],
#             y_range = [-4, 4, 2],
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 2
#             },
#             background_line_style = {
#                 "stroke_color": BLACK,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             }).add_coordinates()
#
#         plane.color = BLACK
#         self.add(plane)
#
#         d1 = Dot(plane.n2p(3 + 1j), color=BLACK, radius=0.04)
#         label1 = MathTex("3 + 2i", color=BLACK, width=13).next_to(d1, UR, 0.05)
#
#         self.add(d1, label1)

# %%
def genPoints(diffFunc, x, y, dx, xrange, yrange):
    points = [(x, y, 0)]
    while (x > xrange[0] and x < xrange[1] and y > yrange[0] and y < yrange[1]):
        m = diffFunc(x, y)
        dy = m * dx
        x = x + dx
        y = y + dy
        points.append((x, y, 0))
    return(points)
    
def genLine(diffFunc, x, y, dx, xrange = [-10, 10], yrange = [-10, 10]):
    a = genPoints(diffFunc, x, y, -dx, xrange, yrange)[1:]
    a.reverse()   
    b = genPoints(diffFunc, x, y, dx, xrange, yrange)
    return(a + b)

def diffFunc(x,y):
    return (x * y) + 1

# %%
# %%manim -v WARNING BasicUsage
#
# config.frame_width = 7
# config.frame_height = 7
#
# class BasicUsage(Scene):
#     def construct(self):
#         func = lambda pos: ((1/sqrt(1 + (diffFunc(pos[0],pos[1]))**2)) * 10 * RIGHT) + (((diffFunc(pos[0],pos[1]))/sqrt(1 + (diffFunc(pos[0],pos[1]))**2)) * 10 * UP)
#         field = ArrowVectorField(func, color = [BLACK], x_range=[-3, 3, 1],y_range=[-3, 3, 1])
#
#         numberplane = NumberPlane(
#         x_range = (-7, 7, 1),
#         y_range = (-7, 7, 1),
#         axis_config = {
#             "color": BLACK,
#             "stroke_width": scale
#         },
#         background_line_style = {
#             "stroke_color": WHITE,
#             "stroke_width": 2,
#             "stroke_opacity": 0.6
#         })
#
#         self.add(numberplane, field)
#
#         c = genLine(diffFunc, 0, 0, 1)
#         for i in range(len(c) - 1):
#             self.add(Line(c[i], c[i + 1], color=BLACK))

# %%
# %%manim -v WARNING BasicUsage
#
# class BasicUsage(Scene):
#     def construct(self):
#         func = lambda pos: ((1/sqrt(1 + (diffFunc(pos[0],pos[1]))**2)) * 10 * RIGHT) + (((diffFunc(pos[0],pos[1]))/sqrt(1 + (diffFunc(pos[0],pos[1]))**2)) * 10 * UP)
#         field = ArrowVectorField(func, color = [BLACK], x_range=[-3, 3, 1],y_range=[-3, 3, 1])
#
#         numberplane = NumberPlane(
#         x_range = (-7, 7, 1),
#         y_range = (-7, 7, 1),
#         axis_config = {
#             "color": BLACK,
#             "stroke_width": scale
#         },
#         background_line_style = {
#             "stroke_color": WHITE,
#             "stroke_width": 2,
#             "stroke_opacity": 0.6
#         })
#
#         self.add(numberplane, field)
#
#         c = genLine(diffFunc, 0, 0, 0.1)
#         for i in range(len(c) - 1):
#             self.add(Line(c[i], c[i + 1], color=BLACK))

# %%
# %%manim -v WARNING PolarPlaneExample
#
# config.frame_width = 4
#
# def PolarCurve(theta):
#         r = np.cos(theta)
#         return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
# def Polar(theta):
#     r = 1
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
# def Spiral(theta):
#     r = theta / (2 * PI)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
# class PolarPlaneExample(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = 4,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             }
#         )
#         curl = ParametricFunction(PolarCurve, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#         curl2 = ParametricFunction(Polar, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#         curl3 = ParametricFunction(Spiral, t_range = np.array([0, 2 * TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#         self.add(polarplane_pi, curl, curl2, curl3)

# %%
# %%manim -v WARNING Sequence
#
# config.frame_width = 12
# config.pixel_width = 1920
# config.pixel_height = 500
#
# shift = LEFT * 6 + DOWN * 1.5
#
# class Sequence(Scene):
#     def construct(self):
#         numberplane = NumberPlane(
#             x_range = (-20, 20, step),
#             y_range = (-4, 4, step),
#             axis_config = {
#                 "color": BLACK,
#                 "stroke_width": scale
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 2,
#                 "stroke_opacity": 0.6
#             }).shift(shift)
#         self.add(numberplane)
#
#         root = FunctionGraph(
#             lambda t: 1 / t,
#             color = BLACK,
#             x_range=[0.01, 15]
#         ).shift(shift)
#         # self.add(root)
#
#         for i in range(1,20):
#             point = Dot(point=[i, 1.5 / i, 0], color = BLACK).shift(shift)
#             self.add(point)

# %%
# %%manim -v WARNING NumberLineExample
#
# class NumberLineExample(Scene):
#     def construct(self):
#         l0 = NumberLine(
#             x_range=[-10, 10, 2],
#             length=10,
#             color=BLACK,
#             include_numbers=True,
#             label_direction=UP,
#         )
#
#         l1 = NumberLine(
#             x_range=[-10, 10, 2],
#             unit_size=0.5,
#             numbers_with_elongated_ticks=[-2, 4],
#             include_numbers=True,
#             font_size=24,
#         )
#         l1.numbers.set_color(BLACK)
#
#         l2 = NumberLine(
#             x_range=[-2.5, 2.5 + 0.5, 0.5],
#             length=12,
#             decimal_number_config={"num_decimal_places": 2},
#             include_numbers=True,
#         )
#
#         l3 = NumberLine(
#             x_range=[-5, 5 + 1, 1],
#             length=6,
#             include_tip=True,
#             include_numbers=True,
#             rotation=10 * DEGREES,
#         )
#
#         line_group = VGroup(l0, l1, l2, l3).arrange(DOWN, buff=1)
#         self.add(line_group)
