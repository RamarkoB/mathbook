# %%
from manim import *
import numpy as np

# %%
scale = 1.5
step = 1

config.background_color = WHITE
config.frame_width = scale * 2
config.pixel_width = 1920
config.pixel_height = 1920

# %%
# %%manim -v WARNING Constant
#
# def func(theta):
#     r = 1
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
# class Constant(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING Sine
#
# def func(theta):
#     r = np.sin(theta)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class Sine(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING Cos
#
# def func(theta):
#     r = np.cos(theta)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class Cos(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING OddSinRose
#
# def func(theta):
#     r = np.sin(3 * theta)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class OddSinRose(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING EvenSinRose
#
# def func(theta):
#     r = np.sin(2 * theta)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class EvenSinRose(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING OddCosRose
#
# def func(theta):
#     r = np.cos(3 * theta)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class OddCosRose(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING EvenCosRose
#
# def func(theta):
#     r = np.cos(2 * theta)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class EvenCosRose(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING LimaconLoop
#
# def func(theta):
#     r = (3/8) + (3/4)*np.sin(theta)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class LimaconLoop(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING Cardioid
#
# def func(theta):
#     r = (4.5/8) + (4.5/8) * np.sin(theta)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class Cardioid(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING LimaconDimpled
#
# def func(theta):
#     r = (5/8) + (4/8)*np.sin(theta)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class LimaconDimpled(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING LimaconConvex
#
# def func(theta):
#     r = (6/8) + (3/8)*np.sin(theta)
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class LimaconConvex(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING SineLemniscate
#
# def func(theta):
#     r = np.sqrt(np.sin(2 * theta))
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
#
# class SineLemniscate(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl1 = ParametricFunction(
#             func,
#             t_range = np.array([0+0.000001, (PI/2) - 0.0000001]),
#             # discontinuities = [0,PI/2],
#             # dt=0.1,
#             fill_opacity=0,
#             stroke_width=3).set_color(BLACK)
#
#         curl2 = ParametricFunction(
#             func,
#             t_range = np.array([PI+0.0000001, (3 * PI/2) - 0.0000001]),
#             fill_opacity=0,
#             stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl1,curl2)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING CosineLemniscate
#
# def func(theta):
#     r = np.sqrt(np.cos(2 * theta))
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
#
# class CosineLemniscate(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl1 = ParametricFunction(
#             func,
#             t_range = np.array([- (PI/4), PI/4]),
#             # discontinuities = [0,PI/2],
#             # dt=0.1,
#             fill_opacity=0,
#             stroke_width=3).set_color(BLACK)
#
#         curl2 = ParametricFunction(
#             func,
#             t_range = np.array([3 * PI / 4 + 0.00001, 5 * PI/4 - 0.00001]),
#             # discontinuities = [0,PI/2],
#             # dt=0.1,
#             fill_opacity=0,
#             stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl1,curl2)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING Spiral
#
# def func(theta):
#     r = (PI / 32) * (1.22) * theta
#     return np.array([r * np.cos(theta), r * np.sin(theta), 0])
#
#
# class Spiral(Scene):
#     def construct(self):
#         polarplane_pi = PolarPlane(
#             azimuth_units="PI radians",
#             size = scale * 2,
#             radius_step = 1,
#             x_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             y_axis_config = {
#                 "color": BLACK,
#                 "stroke_width": 1.5,
#                 "stroke_opacity": 0.45
#             },
#             background_line_style = {
#                 "stroke_color": WHITE,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.3
#             }
#         )
#
#         curl = ParametricFunction(func, t_range = np.array([0, 2 * TAU]), fill_opacity=0, stroke_width=3).set_color(BLACK)
#
#         self.add(polarplane_pi, curl)
# Out:
# Manim Community v0.18.1
